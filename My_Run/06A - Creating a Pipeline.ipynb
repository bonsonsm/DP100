# %% [markdown]
# # Creating a Pipeline
#
# In the previous labs, you used the Azure Machine Learning SDK to explore the entire model training process from accessing data through to running training experiments and registering machine learning models. Up until now, you have performed the various steps required to create a machine learning solution interactively. In this lab, you'll explore automation of these steps using *pipelines*.
#
# ## Connect to Your Workspace
#
# The first thing you need to do is to connect to your workspace using the Azure ML SDK.
#
# > **Note**: If the authenticated session with your Azure subscription has expired since you completed the previous exercise, you'll be prompted to reauthenticate.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.13.0 to work with BSM_MLWorkspace3

# %% [markdown]
# ## Prepare Data for an Experiment
#
# In this lab, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it in the previous lab, the code will find the existing version)

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create Scripts for Pipeline Steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like an Auto ML training estimator or a data transfer step that copies data from one location to another. Each step can run in its own compute context.
#
# In this exercise, you'll build a simple pipeline that contains an estimator step (to train a model) and a Python script step (to register the trained model).

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now you can create the script for the first step, which will train a model. The script includes a parameter named **output_folder**, which references the folder where the trained model should be saved.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--output_folder', type=str, dest='output_folder', default="diabetes_model", help='output folder')
args = parser.parse_args()
output_folder = args.output_folder

# Get the experiment run context
run = Run.get_context()

# load the diabetes data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['diabetes_train'].to_pandas_dataframe()

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model
os.makedirs(output_folder, exist_ok=True)
output_path = output_folder + "/model.pkl"
joblib.dump(value=model, filename=output_path)

run.complete()
# Out:
# Writing diabetes_pipeline/train_diabetes.py

# %% [markdown]
# The script for the second step of the pipeline will load the model from where it was saved, and then register it in the workspace. It includes a single **model_folder** parameter that contains the path where the model was saved.

# %%
# %%writefile $experiment_folder/register_diabetes.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="diabetes_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_file = model_folder + "/model.pkl"
model = joblib.load(model_file)

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Writing diabetes_pipeline/register_diabetes.py

# %% [markdown]
# ## Prepare a Compute Environment for the Pipeline Steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target you created in a previous lab (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "B-ML3-CmpCluster"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so you'll need to create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-experiment-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib', 'pandas'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment (just in case previous lab wasn't completed)
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-experiment-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and Run a Pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to passed between them. In this case, the first step must write the model to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so our code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData("model_folder", datastore=ws.get_default_datastore())

estimator = Estimator(source_directory=experiment_folder,
                        compute_target = pipeline_cluster,
                        environment_definition=pipeline_run_config.environment,
                        entry_script='train_diabetes.py')

train_step = EstimatorStep(name = "Train Model",
                           estimator=estimator, 
                           estimator_entry_script_arguments=['--output_folder', model_folder],
                           inputs=[diabetes_ds.as_named_input('diabetes_train')],
                           outputs=[model_folder],
                           compute_target = pipeline_cluster,
                           allow_reuse = True)

# Step 2, run the model registration script
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = experiment_folder,
                                script_name = "register_diabetes.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'diabetes-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Train Model [4b69b241][230c85c3-a426-4786-81c9-bb8b26d19599], (This step will run and generate new outputs)
# Created step Register Model [01aafa58][5448278e-926d-42a5-9ee1-1ba3ab98344a], (This step will run and generate new outputs)
# Submitted PipelineRun 3b8d6a6c-e927-4e07-9905-d3fb38fa4a15
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/3b8d6a6c-e927-4e07-9905-d3fb38fa4a15?wsid=/subscriptions/94670d96-c488-4d89-a5e8-ea4fef48bf6a/resourcegroups/MS_SolutionCenter/workspaces/BSM_MLWorkspace3
# Pipeline submitted for execution.
# PipelineRunId: 3b8d6a6c-e927-4e07-9905-d3fb38fa4a15
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/3b8d6a6c-e927-4e07-9905-d3fb38fa4a15?wsid=/subscriptions/94670d96-c488-4d89-a5e8-ea4fef48bf6a/resourcegroups/MS_SolutionCenter/workspaces/BSM_MLWorkspace3
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de?wsid=/subscriptions/94670d96-c488-4d89-a5e8-ea4fef48bf6a/resourcegroups/MS_SolutionCenter/workspaces/BSM_MLWorkspace3
# StepRun( Train Model ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/09/03 03:25:51 Downloading source code...
# 2020/09/03 03:25:53 Finished downloading source code
# 2020/09/03 03:25:53 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/09/03 03:25:53 Successfully set up Docker network: acb_default_network
# 2020/09/03 03:25:53 Setting up Docker configuration...
# 2020/09/03 03:25:54 Successfully set up Docker configuration
# 2020/09/03 03:25:54 Logging in to registry: 57eddf13faae4a7292cbe457f54822f1.azurecr.io
# 2020/09/03 03:25:55 Successfully logged into 57eddf13faae4a7292cbe457f54822f1.azurecr.io
# 2020/09/03 03:25:55 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/09/03 03:25:55 Scanning for dependencies...
# 2020/09/03 03:25:56 Successfully scanned dependencies
# 2020/09/03 03:25:56 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# 8e097b52bfb8: Pulling fs layer
# a613a9b4553c: Pulling fs layer
# acc000f01536: Pulling fs layer
# 73eef93b7466: Pulling fs layer
# d5a54c1fb97f: Pulling fs layer
# 1536f6ca931b: Pulling fs layer
# d7b631d130cb: Pulling fs layer
# 75ffe8dfb222: Pulling fs layer
# 86b4bf2f8d5f: Pulling fs layer
# 5335952fa8d3: Pulling fs layer
# 96fa3cc6fe10: Pulling fs layer
# e428dd9daa94: Pulling fs layer
# 73eef93b7466: Waiting
# d5a54c1fb97f: Waiting
# 1536f6ca931b: Waiting
# d7b631d130cb: Waiting
# 75ffe8dfb222: Waiting
# 86b4bf2f8d5f: Waiting
# 5335952fa8d3: Waiting
# 96fa3cc6fe10: Waiting
# e428dd9daa94: Waiting
# acc000f01536: Verifying Checksum
# acc000f01536: Download complete
# a613a9b4553c: Download complete
# 73eef93b7466: Verifying Checksum
# 73eef93b7466: Download complete
# 8e097b52bfb8: Verifying Checksum
# 8e097b52bfb8: Download complete
# 1536f6ca931b: Verifying Checksum
# 1536f6ca931b: Download complete
# d7b631d130cb: Verifying Checksum
# d7b631d130cb: Download complete
# d5a54c1fb97f: Verifying Checksum
# d5a54c1fb97f: Download complete
# 5335952fa8d3: Verifying Checksum
# 5335952fa8d3: Download complete
# StepRun( Train Model ) Status: Running
# 75ffe8dfb222: Verifying Checksum
# 75ffe8dfb222: Download complete
# 96fa3cc6fe10: Verifying Checksum
# 96fa3cc6fe10: Download complete
# e428dd9daa94: Verifying Checksum
# e428dd9daa94: Download complete
# 86b4bf2f8d5f: Verifying Checksum
# 86b4bf2f8d5f: Download complete
# 8e097b52bfb8: Pull complete
# a613a9b4553c: Pull complete
# acc000f01536: Pull complete
# 73eef93b7466: Pull complete
# d5a54c1fb97f: Pull complete
# 1536f6ca931b: Pull complete
# d7b631d130cb: Pull complete
# 75ffe8dfb222: Pull complete
# 86b4bf2f8d5f: Pull complete
# 5335952fa8d3: Pull complete
# 96fa3cc6fe10: Pull complete
# e428dd9daa94: Pull complete
# Digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#  ---> 287916b809d9
# Step 2/15 : USER root
#  ---> Running in b537eb8a7b23
# Removing intermediate container b537eb8a7b23
#  ---> 2740d51715c7
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 8e87a88ffd59
# Removing intermediate container 8e87a88ffd59
#  ---> 08b888bfeb0a
# Step 4/15 : WORKDIR /
#  ---> Running in d94c2517a3cc
# Removing intermediate container d94c2517a3cc
#  ---> 73c9f43a32a0
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 27ae55affab9
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 28ab3100f96b
# Removing intermediate container 28ab3100f96b
#  ---> 5bf1fbf7e5d5
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> f23c5540cc5c
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 64240947f02e
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | #5         |  15%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# pygments-2.6.1       | 687 KB    |            |   0%
# pygments-2.6.1       | 687 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# freetype-2.10.2      | 915 KB    |            |   0%
# freetype-2.10.2      | 915 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# pandas-1.1.1         | 10.5 MB   |            |   0%
# pandas-1.1.1         | 10.5 MB   | #####5     |  56%
# pandas-1.1.1         | 10.5 MB   | ########## | 100%
#
# dbus-1.13.12         | 611 KB    |            |   0%
# dbus-1.13.12         | 611 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######1    |  62%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# pyzmq-19.0.1         | 510 KB    |            |   0%
# pyzmq-19.0.1         | 510 KB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #5         |  16%
# python-3.6.2         | 27.0 MB   | #####1     |  51%
# python-3.6.2         | 27.0 MB   | ########3  |  84%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | #########5 |  96%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# zeromq-4.3.2         | 681 KB    |            |   0%
# zeromq-4.3.2         | 681 KB    | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# ca-certificates-2020 | 132 KB    |            |   0%
# ca-certificates-2020 | 132 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | ########## | 100%
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# joblib-0.16.0        | 210 KB    |            |   0%
# joblib-0.16.0        | 210 KB    | ########## | 100%
#
# expat-2.2.9          | 196 KB    |            |   0%
# expat-2.2.9          | 196 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# pillow-7.2.0         | 673 KB    |            |   0%
# pillow-7.2.0         | 673 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# mkl_fft-1.1.0        | 159 KB    |            |   0%
# mkl_fft-1.1.0        | 159 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 1          |   2%
# mkl-2019.4           | 204.1 MB  | 6          |   6%
# mkl-2019.4           | 204.1 MB  | 9          |   9%
# mkl-2019.4           | 204.1 MB  | #3         |  14%
# mkl-2019.4           | 204.1 MB  | #8         |  18%
# mkl-2019.4           | 204.1 MB  | ##2        |  23%
# mkl-2019.4           | 204.1 MB  | ##6        |  27%
# mkl-2019.4           | 204.1 MB  | ###        |  31%
# mkl-2019.4           | 204.1 MB  | ###5       |  35%
# mkl-2019.4           | 204.1 MB  | ###9       |  40%
# mkl-2019.4           | 204.1 MB  | ####3      |  44%
# mkl-2019.4           | 204.1 MB  | ####8      |  48%
# mkl-2019.4           | 204.1 MB  | #####2     |  52%
# mkl-2019.4           | 204.1 MB  | #####6     |  57%
# mkl-2019.4           | 204.1 MB  | ######     |  61%
# mkl-2019.4           | 204.1 MB  | ######4    |  65%
# mkl-2019.4           | 204.1 MB  | ######9    |  69%
# mkl-2019.4           | 204.1 MB  | #######3   |  73%
# mkl-2019.4           | 204.1 MB  | #######7   |  78%
# mkl-2019.4           | 204.1 MB  | ########2  |  82%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ##5        |  26%
# scipy-1.5.2          | 18.5 MB   | ######9    |  70%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# prompt-toolkit-3.0.7 | 243 KB    |            |   0%
# prompt-toolkit-3.0.7 | 243 KB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# jupyter_client-6.1.6 | 83 KB     |            |   0%
# jupyter_client-6.1.6 | 83 KB     | ########## | 100%
#
# lz4-c-1.9.2          | 253 KB    |            |   0%
# lz4-c-1.9.2          | 253 KB    | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | #######8   |  79%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | ##6        |  27%
# icu-58.2             | 22.7 MB   | ######5    |  66%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# pip-20.2.2           | 2.0 MB    |            |   0%
# pip-20.2.2           | 2.0 MB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 6          |   7%
# qt-5.9.6             | 86.7 MB   | #6         |  17%
# qt-5.9.6             | 86.7 MB   | ##6        |  27%
# qt-5.9.6             | 86.7 MB   | ###4       |  35%
# qt-5.9.6             | 86.7 MB   | ####4      |  45%
# qt-5.9.6             | 86.7 MB   | #####5     |  55%
# qt-5.9.6             | 86.7 MB   | ######5    |  66%
# qt-5.9.6             | 86.7 MB   | #######6   |  76%
# qt-5.9.6             | 86.7 MB   | ########7  |  88%
# qt-5.9.6             | 86.7 MB   | #########7 |  98%
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ######6    |  66%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | #######2   |  73%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# setuptools-49.6.0    | 927 KB    |            |   0%
# setuptools-49.6.0    | 927 KB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.en587qx8.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.13.0
#   Downloading azureml_defaults-1.13.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.1.0-py3-none-any.whl (28.2 MB)
# Collecting pyarrow
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.13.0
#   Downloading azureml_dataset_runtime-1.13.0-py3-none-any.whl (3.2 kB)
# Collecting azureml-core~=1.13.0
#   Downloading azureml_core-1.13.0-py3-none-any.whl (2.0 MB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azure-identity<2.0.0,>=1.2.0
#   Downloading azure_identity-1.4.0-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-native<21.0.0,>=20.0.2
#   Downloading azureml_dataprep_native-20.0.2-cp36-cp36m-manylinux1_x86_64.whl (10.7 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.en587qx8.requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.en587qx8.requirements.txt (line 2)) (1.19.1)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-defaults~=1.13.0->-r /azureml-environment-setup/condaenv.en587qx8.requirements.txt (line 1)) (2020.1)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-10.2.0-py2.py3-none-any.whl (968 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-defaults~=1.13.0->-r /azureml-environment-setup/condaenv.en587qx8.requirements.txt (line 1)) (2.8.1)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting docker
#   Downloading docker-4.3.1-py2.py3-none-any.whl (145 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.18-py2.py3-none-any.whl (84 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.1-cp35-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.13.0->-r /azureml-environment-setup/condaenv.en587qx8.requirements.txt (line 1)) (1.15.0)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.4.3-py2.py3-none-any.whl (49 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.8.0-py2.py3-none-any.whl (121 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.13.0->azureml-defaults~=1.13.0->-r /azureml-environment-setup/condaenv.en587qx8.requirements.txt (line 1)) (2020.6.20)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.2-cp36-cp36m-manylinux1_x86_64.whl (400 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: json-logging-py, fusepy, dill, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=aa0d4e85e52822a5bbe3610b24a1720fccb1cd7e8d6a89cb5147bce612119db3
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=b027c0e5e6f4ccb04913df7018ab6accee58095bc4fef8f35adf1ae7052e68f9
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=043d0b8c9cd4117d143fdae0aadb753208c74ab9b9c42fdd54ca037db5448f74
#   Stored in directory: /root/.cache/pip/wheels/02/49/cf/660924cd9bc5fcddc3a0246fe39800c83028d3ccea244de352
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=8ca38be2430b8cf6bbd476bf5c5118acfda7e4521477050d066171881e4f4522
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy dill liac-arff
# Installing collected packages: applicationinsights, configparser, pyarrow, pycparser, cffi, cryptography, PyJWT, chardet, idna, urllib3, requests, msal, azure-core, portalocker, msal-extensions, azure-identity, azureml-dataprep-native, distro, dotnetcore2, cloudpickle, azureml-dataprep, fusepy, azureml-dataset-runtime, ruamel.yaml.clib, ruamel.yaml, zipp, importlib-metadata, jsonpickle, oauthlib, requests-oauthlib, isodate, msrest, adal, msrestazure, pyopenssl, pyasn1, ndg-httpsclient, azure-common, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-storage, jeepney, SecretStorage, pathspec, backports.weakref, backports.tempfile, azure-mgmt-authorization, websocket-client, docker, jmespath, contextlib2, azure-graphrbac, azure-mgmt-containerregistry, azureml-core, dill, liac-arff, azureml-model-management-sdk, gunicorn, werkzeug, json-logging-py, itsdangerous, MarkupSafe, Jinja2, click, flask, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.8.0 azure-graphrbac-0.61.1 azure-identity-1.4.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-10.2.0 azure-mgmt-storage-11.2.0 azureml-core-1.13.0 azureml-dataprep-2.1.0 azureml-dataprep-native-20.0.2 azureml-dataset-runtime-1.13.0 azureml-defaults-1.13.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.2 chardet-3.0.4 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.1 dill-0.3.2 distro-1.5.0 docker-4.3.1 dotnetcore2-2.1.14 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-1.7.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.5.0 msal-1.4.3 msal-extensions-0.2.2 msrest-0.6.18 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.0 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 requests-2.24.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 urllib3-1.25.10 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 64240947f02e
#  ---> 8c1a879a0f64
# Step 9/15 : ENV PATH /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/bin:$PATH
#  ---> Running in 1cf43bbef548
# Removing intermediate container 1cf43bbef548
#  ---> 9e1199e71059
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf
#  ---> Running in a34a0b4dbffe
# Removing intermediate container a34a0b4dbffe
#  ---> 4f7aef77ff4d
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/lib:$LD_LIBRARY_PATH
#  ---> Running in 514e7f51b0e3
# Removing intermediate container 514e7f51b0e3
#  ---> b98299a891e6
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 1808f9da789e
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in e09db264157b
# Removing intermediate container e09db264157b
#  ---> 9001ce5cf141
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in ae4509ea070f
# Removing intermediate container ae4509ea070f
#  ---> 7289fd76ed91
# Step 15/15 : CMD ["bash"]
#  ---> Running in bf61bfb6e969
# Removing intermediate container bf61bfb6e969
#  ---> 521e89eb4268
# Successfully built 521e89eb4268
# Successfully tagged 57eddf13faae4a7292cbe457f54822f1.azurecr.io/azureml/azureml_7aed198732bee1a2e79b18d35a050421:latest
# 2020/09/03 03:30:45 Successfully executed container: acb_step_0
# 2020/09/03 03:30:45 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/09/03 03:30:45 Pushing image: 57eddf13faae4a7292cbe457f54822f1.azurecr.io/azureml/azureml_7aed198732bee1a2e79b18d35a050421:latest, attempt 1
# The push refers to repository [57eddf13faae4a7292cbe457f54822f1.azurecr.io/azureml/azureml_7aed198732bee1a2e79b18d35a050421]
# 872199ac80e5: Preparing
# 4005bd8996b4: Preparing
# 0212ec9e8fd2: Preparing
# eb693decbd35: Preparing
# 1892fd42b0bf: Preparing
# be9ff37c12fa: Preparing
# 13e378616f24: Preparing
# efc99d952c3d: Preparing
# 9e292a80b88a: Preparing
# 5e1805eb9eb5: Preparing
# 8dab94e6d05c: Preparing
# 2817caf0a082: Preparing
# aece08fd27fc: Preparing
# 4caea5ef1f0b: Preparing
# dcc0cc99372e: Preparing
# 87c128261339: Preparing
# 41a253a417e6: Preparing
# e06660e80cf4: Preparing
# be9ff37c12fa: Waiting
# 13e378616f24: Waiting
# efc99d952c3d: Waiting
# 9e292a80b88a: Waiting
# 5e1805eb9eb5: Waiting
# 8dab94e6d05c: Waiting
# 2817caf0a082: Waiting
# aece08fd27fc: Waiting
# 4caea5ef1f0b: Waiting
# dcc0cc99372e: Waiting
# 87c128261339: Waiting
# 41a253a417e6: Waiting
# e06660e80cf4: Waiting
# 872199ac80e5: Pushed
# 1892fd42b0bf: Pushed
# 0212ec9e8fd2: Pushed
# eb693decbd35: Pushed
# be9ff37c12fa: Pushed
# efc99d952c3d: Pushed
# 13e378616f24: Pushed
# 9e292a80b88a: Pushed
#
# 2817caf0a082: Pushed
# aece08fd27fc: Pushed
# dcc0cc99372e: Pushed
# 87c128261339: Pushed
# 41a253a417e6: Pushed
# 8dab94e6d05c: Pushed
# 5e1805eb9eb5: Pushed
# e06660e80cf4: Pushed
# 4caea5ef1f0b: Pushed
#
# 4005bd8996b4: Pushed
# latest: digest: sha256:29be576924dbc409f05d8775cc3397835f2329f938634067d4ced91c65dcdde0 size: 4095
# 2020/09/03 03:33:43 Successfully pushed image: 57eddf13faae4a7292cbe457f54822f1.azurecr.io/azureml/azureml_7aed198732bee1a2e79b18d35a050421:latest
# 2020/09/03 03:33:43 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 289.538505)
# 2020/09/03 03:33:43 Populating digests for step ID: acb_step_0...
# 2020/09/03 03:33:45 Successfully populated digests for step ID: acb_step_0
# 2020/09/03 03:33:45 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 178.188811)
# 2020/09/03 03:33:45 The following dependencies were found:
# 2020/09/03 03:33:45
# - image:
#     registry: 57eddf13faae4a7292cbe457f54822f1.azurecr.io
#     repository: azureml/azureml_7aed198732bee1a2e79b18d35a050421
#     tag: latest
#     digest: sha256:29be576924dbc409f05d8775cc3397835f2329f938634067d4ced91c65dcdde0
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200821.v1
#     digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#   git: {}
#
# Run ID: ch2 was successful after 7m55s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768cc552dd55d06dbfd_d.txt
# ========================================================================================================================
# 2020-09-03T03:37:42Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2020-09-03T03:37:42Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# 2020-09-03T03:37:42Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-09-03T03:37:42Z Starting output-watcher...
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_7aed198732bee1a2e79b18d35a050421
# 8e097b52bfb8: Pulling fs layer
# a613a9b4553c: Pulling fs layer
# acc000f01536: Pulling fs layer
# 73eef93b7466: Pulling fs layer
# d5a54c1fb97f: Pulling fs layer
# 1536f6ca931b: Pulling fs layer
# d7b631d130cb: Pulling fs layer
# 75ffe8dfb222: Pulling fs layer
# 86b4bf2f8d5f: Pulling fs layer
# 5335952fa8d3: Pulling fs layer
# 96fa3cc6fe10: Pulling fs layer
# e428dd9daa94: Pulling fs layer
# e83dfffd0616: Pulling fs layer
# 2e6f06ab23bd: Pulling fs layer
# c78344079ff3: Pulling fs layer
# eefa0556fd14: Pulling fs layer
# b2ad0f523458: Pulling fs layer
# f4205e126943: Pulling fs layer
# 73eef93b7466: Waiting
# d5a54c1fb97f: Waiting
# 1536f6ca931b: Waiting
# 5335952fa8d3: Waiting
# d7b631d130cb: Waiting
# 96fa3cc6fe10: Waiting
# 75ffe8dfb222: Waiting
# e428dd9daa94: Waiting
# 2e6f06ab23bd: Waiting
# 86b4bf2f8d5f: Waiting
# f4205e126943: Waiting
# eefa0556fd14: Waiting
# acc000f01536: Verifying Checksum
# acc000f01536: Download complete
# a613a9b4553c: Verifying Checksum
# a613a9b4553c: Download complete
# 73eef93b7466: Download complete
# 8e097b52bfb8: Verifying Checksum
# 8e097b52bfb8: Download complete
# 1536f6ca931b: Verifying Checksum
# 1536f6ca931b: Download complete
# d5a54c1fb97f: Verifying Checksum
# d5a54c1fb97f: Download complete
# 75ffe8dfb222: Verifying Checksum
# 75ffe8dfb222: Download complete
# 5335952fa8d3: Verifying Checksum
# 5335952fa8d3: Download complete
# 86b4bf2f8d5f: Verifying Checksum
# 86b4bf2f8d5f: Download complete
# d7b631d130cb: Verifying Checksum
# d7b631d130cb: Download complete
# e428dd9daa94: Verifying Checksum
# e428dd9daa94: Download complete
# 2e6f06ab23bd: Verifying Checksum
# 2e6f06ab23bd: Download complete
# 96fa3cc6fe10: Verifying Checksum
# 96fa3cc6fe10: Download complete
# eefa0556fd14: Verifying Checksum
# eefa0556fd14: Download complete
# c78344079ff3: Verifying Checksum
# c78344079ff3: Download complete
# e83dfffd0616: Download complete
# f4205e126943: Verifying Checksum
# f4205e126943: Download complete
# 8e097b52bfb8: Pull complete
# a613a9b4553c: Pull complete
# acc000f01536: Pull complete
# 73eef93b7466: Pull complete
# b2ad0f523458: Verifying Checksum
# b2ad0f523458: Download complete
# d5a54c1fb97f: Pull complete
# 1536f6ca931b: Pull complete
# d7b631d130cb: Pull complete
# 75ffe8dfb222: Pull complete
# 86b4bf2f8d5f: Pull complete
# 5335952fa8d3: Pull complete
# 96fa3cc6fe10: Pull complete
# e428dd9daa94: Pull complete
# e83dfffd0616: Pull complete
# 2e6f06ab23bd: Pull complete
# c78344079ff3: Pull complete
# eefa0556fd14: Pull complete
# b2ad0f523458: Pull complete
# f4205e126943: Pull complete
# Digest: sha256:29be576924dbc409f05d8775cc3397835f2329f938634067d4ced91c65dcdde0
# Status: Downloaded newer image for 57eddf13faae4a7292cbe457f54822f1.azurecr.io/azureml/azureml_7aed198732bee1a2e79b18d35a050421:latest
# 1eb296258fcf27665b46e639e14099325a04f6ab8150767397aa607429a6db48
# 2020/09/03 03:38:55 setuptask.go:353: Starting App Insight Logger for task:  containerSetup
# 2020/09/03 03:38:55 logger.go:293: Version: 3.0.01321.0003 Branch: .SourceBranch Commit: 8fd8782
# 2020/09/03 03:38:55 utils.go:302: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/09/03 03:38:55 logger.go:293: sshd inside container not required for job, skipping setup.
# 2020/09/03 03:38:55 appinsightlogger.go:40: All App Insights Logs was send successfully
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# [2020-09-03T03:39:01.892423] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['train_diabetes.py', '--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/mounts/aml_data/azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/model_folder'])
# Starting the daemon thread to refresh tokens in background for process with pid = 121
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/mounts/workspaceblobstore/azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de
# Preparing to call script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/mounts/aml_data/azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/model_folder']
# After variable expansion, calling script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/mounts/aml_data/azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/model_folder']
#
# Script type = None
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8993333333333333
# AUC: 0.8853989246160638
#
# Streaming azureml-logs/75_job_post-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768cc552dd55d06dbfd_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-09-03T03:39:35.707031
# Starting job release. Current time:2020-09-03T03:39:36.679804
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 390
# [2020-09-03T03:39:36.680944] job release stage : upload_datastore starting...
# [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-09-03T03:39:36.688587] job release stage : execute_job_release starting...
# [2020-09-03T03:39:36.689549] job release stage : copy_batchai_cached_logs starting...
# [2020-09-03T03:39:36.689879] job release stage : copy_batchai_cached_logs completed...
# [2020-09-03T03:39:36.690270] Entering context manager injector.
# [2020-09-03T03:39:36.918418] job release stage : upload_datastore completed...
# [2020-09-03T03:39:36.956547] job release stage : send_run_telemetry starting...
# [2020-09-03T03:39:37.175861] job release stage : execute_job_release completed...
# [2020-09-03T03:39:37.179678] job release stage : send_run_telemetry completed...
# Job release is complete. Current time:2020-09-03T03:39:37.179815
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': '37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de', 'target': 'B-ML3-CmpCluster', 'status': 'Completed', 'startTimeUtc': '2020-09-03T03:37:35.648687Z', 'endTimeUtc': '2020-09-03T03:39:45.098017Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '4125fa8b-d59d-4de9-bc27-fc72cf4896e1', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '230c85c3-a426-4786-81c9-bb8b26d19599', 'azureml.nodeid': '4b69b241', 'azureml.pipelinerunid': '3b8d6a6c-e927-4e07-9905-d3fb38fa4a15', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '52288474-1e3e-4194-aadb-1123fc802652'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_train', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'B-ML3-CmpCluster', 'dataReferences': {'model_folder': {'dataStoreName': 'aml_data', 'mode': 'Mount', 'pathOnDataStore': 'azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'diabetes_train': {'dataLocation': {'dataset': {'id': '52288474-1e3e-4194-aadb-1123fc802652', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_train', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'diabetes-experiment-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.13.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas'], 'name': 'azureml_89bb01b798b4fa58c7defa99b5a77fbf'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://bsmmlworkspace6998297976.blob.core.windows.net/azureml/ExperimentRun/dcid.37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=WLWvmkevmLIG5Ippu4twqviIo8u0k0jh7NvwOah23vA%3D&st=2020-09-03T03%3A29%3A38Z&se=2020-09-03T11%3A39%3A38Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768 ...
# StepRunId: 8a031ad4-c291-4085-a340-3f9fbfa06b02
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/8a031ad4-c291-4085-a340-3f9fbfa06b02?wsid=/subscriptions/94670d96-c488-4d89-a5e8-ea4fef48bf6a/resourcegroups/MS_SolutionCenter/workspaces/BSM_MLWorkspace3
# StepRun( Register Model ) Status: NotStarted
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768cc552dd55d06dbfd_d.txt
# ========================================================================================================================
# 2020-09-03T03:40:14Z Starting output-watcher...
# 2020-09-03T03:40:14Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2e2810d38d3b84b7b65958c3c218d774b9cd031fec74667ebdcca8f4279716ba
# 2020/09/03 03:40:15 setuptask.go:353: Starting App Insight Logger for task:  containerSetup
# 2020/09/03 03:40:15 logger.go:293: Version: 3.0.01321.0003 Branch: .SourceBranch Commit: 8fd8782
# 2020/09/03 03:40:15 utils.go:302: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/09/03 03:40:15 logger.go:293: sshd inside container not required for job, skipping setup.
# 2020/09/03 03:40:16 appinsightlogger.go:40: All App Insights Logs was send successfully
# 2020-09-03T03:40:21Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2020/09/03 03:40:11 setuptask.go:353: Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/09/03 03:40:11 logger.go:293: Version: 3.0.01321.0003 Branch: .SourceBranch Commit: 8fd8782
# >>>   2020/09/03 03:40:11 dynamicconfigs.go:17: Reading dyanamic configs
# >>>   2020/09/03 03:40:11 selfupdate.go:181: Container sas url: https://baiscriptseastus2prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=jCOdu9JYnzJiH4sLkyP8uB30%2BkOIOkA489fe%2BjeZkEs%3D
# >>>   2020/09/03 03:40:11 logger.go:293: [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false
# >>>   2020/09/03 03:40:11 logger.go:293: azsecpack isEnable:false
# >>>   2020/09/03 03:40:11 logger.go:293: DetonationChamber is not enabled on this subscription: 94670d96-c488-4d89-a5e8-ea4fef48bf6a
# >>>   2020/09/03 03:40:11 logger.go:293: GPU count found: 0
# >>>   2020/09/03 03:40:11 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02/config
# ...
# >>>   2020/09/03 03:40:17 logger.go:293: runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02/mounts/workspaceblobstore/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02/azureml_compute_logs/65_job_prep-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768cc552dd55d06dbfd_d.txt
# >>>   2020/09/03 03:40:17 logger.go:293: native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02/mounts/workspaceblobstore/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02;/azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/bin/python /mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02/mounts/workspaceblobstore/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4125fa8b-d59d-4de9-bc27-fc72cf4896e1","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/09/03 03:40:17 logger.go:293: runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t 8a031ad4-c291-4085-a340-3f9fbfa06b02 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02/mounts/workspaceblobstore/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02;/azureml-envs/azureml_89bb01b798b4fa58c7defa99b5a77fbf/bin/python /mnt/batch/tasks/shared/LS_root/jobs/bsm_mlworkspace3/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02/mounts/workspaceblobstore/azureml/8a031ad4-c291-4085-a340-3f9fbfa06b02-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4125fa8b-d59d-4de9-bc27-fc72cf4896e1","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:17.662264] Entering job preparation.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:18.358836] TimeoutHandler __init__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:18.358871] TimeoutHandler __enter__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:18.360067] Starting job preparation.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:18.360090] Extracting the control code.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:18.396301] fetching and extracting the control code on master node.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:18.396347] Starting extract_project.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:18.396415] Starting to extract zip file.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.238587] Finished extracting zip file.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.422459] Using urllib.request Python 3.0 or later
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.422520] Start fetching snapshots.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.422597] Start fetching snapshot.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.422631] Retrieving project from snapshot: 4125fa8b-d59d-4de9-bc27-fc72cf4896e1
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 59
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.423571] Start RetrieveProjectSasUrls
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.703138] Finished RetrieveProjectSasUrls
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.703222] TimeoutHandler __init__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.703235] TimeoutHandler __enter__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.704489] TimeoutHandler __exit__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.704538] Starting project file download.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.704604] Starting _download_tree for file.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.704721] _download_tree start request for file
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.743528] _download_tree finished request for file
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.743578] _download_tree start writing file
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.743593] TimeoutHandler __init__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.743622] TimeoutHandler __enter__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.810023] TimeoutHandler __exit__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.810071] _download_tree finished writing file
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.810103] Starting _download_tree for file.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.810495] _download_tree start request for file
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.829308] _download_tree finished request for file
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.829332] _download_tree start writing file
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.829341] TimeoutHandler __init__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.829367] TimeoutHandler __enter__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.847503] TimeoutHandler __exit__
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.847528] _download_tree finished writing file
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.847546] Finished project file download.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.847566] Finished fetching snapshot.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.847597] Finished fetching snapshots.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.847602] Finished extract_project.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.865932] Finished fetching and extracting the control code.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.868621] downloadDataStore - Download from datastores if requested.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.869441] Start run_history_prep.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:19.928494] Entering context manager injector.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: Acquired lockfile /tmp/8a031ad4-c291-4085-a340-3f9fbfa06b02-datastore.lock to downloading input data references
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:21.231427] downloadDataStore completed
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:21.234902] Job preparation is complete.
# >>>   2020/09/03 03:40:21 logger.go:293: runSpecialJobTask: preparation: [2020-09-03T03:40:21.235051] TimeoutHandler __exit__
# >>>   2020/09/03 03:40:21 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>   2020/09/03 03:40:21 logger.go:293: Process Exiting with Code:  0
# >>>
# 2020-09-03T03:40:21Z 127.0.0.1 slots=4 max-slots=4
# 2020-09-03T03:40:21Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768cc552dd55d06dbfd_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-09-03T03:40:32.725998
# Starting job release. Current time:2020-09-03T03:40:33.694042
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 159
# [2020-09-03T03:40:33.704312] job release stage : upload_datastore starting...
# [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-09-03T03:40:33.705055] job release stage : execute_job_release starting...
# [2020-09-03T03:40:33.707171] job release stage : copy_batchai_cached_logs starting...
# [2020-09-03T03:40:33.712437] job release stage : copy_batchai_cached_logs completed...
# [2020-09-03T03:40:33.713487] Entering context manager injector.
# [2020-09-03T03:40:34.023364] job release stage : upload_datastore completed...
# [2020-09-03T03:40:34.096601] job release stage : send_run_telemetry starting...
# [2020-09-03T03:40:34.222457] job release stage : execute_job_release completed...
# [2020-09-03T03:40:34.317166] job release stage : send_run_telemetry completed...
# Job release is complete. Current time:2020-09-03T03:40:34.317355
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '8a031ad4-c291-4085-a340-3f9fbfa06b02', 'target': 'B-ML3-CmpCluster', 'status': 'Completed', 'startTimeUtc': '2020-09-03T03:40:14.646944Z', 'endTimeUtc': '2020-09-03T03:40:40.740974Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '4125fa8b-d59d-4de9-bc27-fc72cf4896e1', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '5448278e-926d-42a5-9ee1-1ba3ab98344a', 'azureml.nodeid': '01aafa58', 'azureml.pipelinerunid': '3b8d6a6c-e927-4e07-9905-d3fb38fa4a15', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'register_diabetes.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'B-ML3-CmpCluster', 'dataReferences': {'model_folder': {'dataStoreName': 'aml_data', 'mode': 'Mount', 'pathOnDataStore': 'azureml/37724ed7-40e5-4b9f-9ee1-b3f5acf1b3de/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'diabetes-experiment-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.13.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas'], 'name': 'azureml_89bb01b798b4fa58c7defa99b5a77fbf'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768cc552dd55d06dbfd_d.txt': 'https://bsmmlworkspace6998297976.blob.core.windows.net/azureml/ExperimentRun/dcid.8a031ad4-c291-4085-a340-3f9fbfa06b02/azureml-logs/55_azureml-execution-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768cc552dd55d06dbfd_d.txt?sv=2019-02-02&sr=b&sig=zQFCFEUyuz1%2F78WGzIFcawd1ojjclpVj0szENDNrYc0%3D&st=2020-09-03T03%3A30%3A36Z&se=2020-09-03T11%3A40%3A36Z&sp=r', 'azureml-logs/65_job_prep-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768cc552dd55d06dbfd_d.txt': 'https://bsmmlworkspace6998297976.blob.core.windows.net/azureml/ExperimentRun/dcid.8a031ad4-c291-4085-a340-3f9fbfa06b02/azureml-logs/65_job_prep-tvmps_b9e76a58abcac63e8b113b9a905ec63e78c7dcc135972768cc552dd55d06dbfd_d.txt?sv=2019-02-02&sr=b& ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '3b8d6a6c-e927-4e07-9905-d3fb38fa4a15', 'status': 'Completed', 'startTimeUtc': '2020-09-03T03:25:35.111762Z', 'endTimeUtc': '2020-09-03T03:40:51.17896Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://bsmmlworkspace6998297976.blob.core.windows.net/azureml/ExperimentRun/dcid.3b8d6a6c-e927-4e07-9905-d3fb38fa4a15/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=IWxa2y6xe%2Bn1V9MR5TEV2iRTCiDMB3huDuqnRDBcxGI%3D&st=2020-09-03T03%3A30%3A52Z&se=2020-09-03T11%3A40%3A52Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://bsmmlworkspace6998297976.blob.core.windows.net/azureml/ExperimentRun/dcid.3b8d6a6c-e927-4e07-9905-d3fb38fa4a15/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=1OJ3QgKRsTh3VOVSYzXsGZKWPmfzyD9FXWMXtvHcVh4%3D&st=2020-09-03T03%3A30%3A52Z&se=2020-09-03T11%3A40%3A52Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://bsmmlworkspace6998297976.blob.core.windows.net/azureml/ExperimentRun/dcid.3b8d6a6c-e927-4e07-9905-d3fb38fa4a15/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=L79Y%2F6FcfcxhVgxwXyzIfbTuBsbyuM8iG7XQxbDCM8s%3D&st=2020-09-03T03%3A30%3A52Z&se=2020-09-03T11%3A40%3A52Z&sp=r'}}
# 'Finished'

# %% [markdown]
# The output from the pipeline experiment will be displayed as it runs. keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 9
# 	 Training context : Pipeline
#
#
# diabetes_model version: 8
# 	 Training context : Azure ML compute
# 	 AUC : 0.8863989679711839
# 	 Accuracy : 0.9004444444444445
#
#
# diabetes_model version: 7
# 	 Training context : Estimator + Environment (Decision Tree)
# 	 AUC : 0.8822545724167647
# 	 Accuracy : 0.8968888888888888
#
#
# diabetes_model version: 6
# 	 Training context : Estimator + Environment (Decision Tree)
# 	 AUC : 0.8841057918016353
# 	 Accuracy : 0.8997777777777778
#
#
# diabetes_model version: 5
# 	 Training context : SKLearn Estimator (file dataset)
# 	 AUC : 0.8568655044545174
# 	 Accuracy : 0.7893333333333333
#
#
# diabetes_model version: 4
# 	 Training context : SKLearn Estimator (tabular dataset)
# 	 AUC : 0.8568613016622707
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 3
# 	 Training context : Using Datastore
# 	 AUC : 0.8568655044545174
# 	 Accuracy : 0.7893333333333333
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized SKLearn Estimator
# 	 AUC : 0.8483904671874223
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 1
# 	 Training context : Estimator
# 	 AUC : 0.8484929598487486
# 	 Accuracy : 0.774

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
